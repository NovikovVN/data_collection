# %%
import os
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs
from glob import glob
from time import sleep

# %% [markdown]
# **1). Необходимо собрать информацию о вакансиях на должность программиста или разработчика с сайта superjob.ru или hh.ru. (Можно с обоих сразу) Приложение должно анализировать несколько страниц сайта. Получившийся список должен содержать в себе: **
#
#  - Наименование вакансии,
#  - Предлагаемую зарплату,
#  - Ссылку на саму вакансию
#
# **2). Доработать приложение таким образом, чтобы можно было искать разработчиков на разные языки программирования (Например Python, Java, C++)**

# %%
columns = ['vacancy', 'snippet', 'salary', 'employer', 'vacancy_link']
hh = pd.DataFrame(columns=columns)
sj = pd.DataFrame(columns=columns)

# %% [markdown]
# Через парсинг сохраненных страниц сайта hh.ru получим данные по вакансиям:

# %%
for file_name in glob(os.path.join('hh', '*.html')):
    with open(file_name, 'rb') as f:
        parser = bs(f, 'html.parser')
        vacancies = parser.find_all('div', {'class': 'vacancy-serp-item'})
        for v in vacancies:
            vacancy = v.find('a', {'class': 'bloko-link HH-LinkModifier'}, href=True)
            snippet = v.find('div', {'data-qa': "vacancy-serp__vacancy_snippet_requirement"})
            salary_info = v.find('div', {'class': "vacancy-serp-item__compensation"})
            if salary_info:
                salary = salary_info.get_text()
            else:
                salary = '-'
            employer = v.find('a', {'data-qa': "vacancy-serp__vacancy-employer"})
            vacancy_link = vacancy['href']
            vacancy_info = {
                'vacancy': vacancy.get_text(),
                'snippet': snippet.get_text(),
                'salary': salary,
                'employer': employer.get_text(),
                'vacancy_link': vacancy_link,
            } 
            hh = hh.append(vacancy_info, ignore_index=True)

# %% [markdown]
# Поправим немного ссылки:

# %%
hh['vacancy_link'] = hh['vacancy_link'].str.replace('[?]query=.+', '', regex=True)

# %%
hh.head()
# Out:
#                                              vacancy  \
# 0                                    Программист С++
# 1                                 Программист С++/Qt
# 2  Full-Stack Разработчик JavaScript (Node.js + A...
# 3                      Программист (C#\ ASP.NET\MVC)
# 4                    Web-программист/PHP-программист
#
#                                              snippet               salary  \
# 0  Отличное знание C++. Умение разбираться в чужо...  60 000-100 000 руб.
# 1  QT framework. Знание паттернов, разработка мно...  60 000-100 000 руб.
# 2  JavaScript / TypeScript (идеальное владение). ...      от 120 000 руб.
# 3  Высшее профильное образование. Опыт разработки...      от 100 000 руб.
# 4  Знание PHP, MySQL‚ HTML‚ CSS‚ JavaScript. - Оп...                    -
#
#                      employer                    vacancy_link
# 0              Cappasity Inc.  https://hh.ru/vacancy/32323917
# 1              Cappasity Inc.  https://hh.ru/vacancy/31273030
# 2  ИП Бушев Юрий Владимирович  https://hh.ru/vacancy/32859767
# 3                    ООО МИЮИ  https://hh.ru/vacancy/33036570
# 4                     Онлишар  https://hh.ru/vacancy/32728996

# %% [markdown]
# Через запросы на сайт superjob.ru и парсинг результатов запроса получим данные по вакансиям:

# %%
for page in ['', '?page=2', '?page=5']:
    url = 'https://www.superjob.ru/vakansii/programmist.html' + page
    sleep(6)
    r = requests.get(url)
    print(r)
    parser = bs(r.text, 'html.parser')
    vacancies = parser.find_all('div', {'class': '_3zucV _2GPIV i6-sc _3VcZr'})
    for v in vacancies:
        vacancy = v.find('div', {'class': '_3mfro CuJz5 PlM3e _2JVkc _3LJqf'})
        salary = v.find('span', {'class': 'f-test-text-company-item-salary'}).get_text()
        salary = salary.replace('По договорённости', '')
        employer_info = v.find('span', {'class': 'f-test-text-vacancy-item-company-name'})
        if employer_info:
            employer = employer_info.get_text()
        else:
            employer = '-'
        snippet_info = v.find_all('span', {'class': '_3mfro _9fXTd _2JVkc _2VHxz'})
        if len(snippet_info) == 2:
            snippet = snippet_info[0].get_text().replace('Должностные обязанности: ', '')
            snippet += snippet_info[1].get_text().replace('Требования:', '')
        else:
            snippet = '-'
        vacancy_link = v.find('a', {'class': '_1QIBo'}, href=True)['href']
        vacancy_link = 'https://www.superjob.ru' + vacancy_link
        vacancy_info = {
                    'vacancy': vacancy.get_text(),
                    'snippet': snippet,
                    'salary': salary,
                    'employer': employer,
                    'vacancy_link': vacancy_link,
                }
        sj = sj.append(vacancy_info, ignore_index=True)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %% [markdown]
# Поправим немного зарплату:

# %%
sj['salary'] = sj['salary'].str.replace('По договорённости', '-', regex=False)
sj['salary'] = sj['salary'].str.replace('₽', 'руб.', regex=False)

# %%
sj.head()
# Out:
#                          vacancy  \
# 0                Web-программист
# 1                 Программист 1С
# 2                 Программист 1С
# 3  Программист 1С (Производство)
# 4     Программист-разработчик 1С
#
#                                              snippet           salary  \
# 0  Центр по разработке ПО в сфере логистики пригл...     150 000 руб.
# 1  Разработка и внедрение программного продукта в...  от 100 000 руб.
# 2  Центр по разработке ПО в сфере логистики пригл...     150 000 руб.
# 3  Поддержка нетиповой конфигурации на базе Управ...     120 000 руб.
# 4  Участие в разработке и внедрениях сложных (в т...  от 120 000 руб.
#
#                                      employer  \
# 0  Кадровое агентство уникальных специалистов
# 1                         Группа компаний ЦВТ
# 2  Кадровое агентство уникальных специалистов
# 3                         Группа компаний ПиР
# 4                                  Device PRO
#
#                                         vacancy_link
# 0  https://www.superjob.ru/vakansii/web-programmi...
# 1  https://www.superjob.ru/vakansii/programmist-1...
# 2  https://www.superjob.ru/vakansii/programmist-1...
# 3  https://www.superjob.ru/vakansii/programmist-1...
# 4  https://www.superjob.ru/vakansii/programmist-r...

# %% [markdown]
# Объединим в датафрейм полученные данные с hh.ru и superjob.ru:

# %%
df = pd.concat([hh, sj], ignore_index=True)

# %% [markdown]
# Напишем функцию, которая фильтрует записи датафрейма по названию языка в столбцах с названием и описанием вакансии.
# Сортируем их по зарплате - по убыванию:

# %%
def filter_vacancies(l, df):
    idx = df['vacancy'].str.contains(l, regex=False) | \
          df['snippet'].str.contains(l, regex=False)
    return df[idx].sort_values(by='salary', ascending=False)

# %% [markdown]
# Отфильтруем в датафрейме вакансии по С++:

# %%
filter_vacancies('С++', df=df)
# Out:
#                                          vacancy  \
# 72                               Программист C++
# 136            Ведущий инженер-программист C/C++
# 5                              Программист C/С++
# 8                        Программист iOS (Swift)
# 37                     Программист С++ (графика)
# 135                          Инженер-программист
# 47                           Программист Android
# 1                             Программист С++/Qt
# 0                                Программист С++
# 119            Руководитель группы программистов
# 15       Стажер-разработчик бекэнда (С++/Python)
# 14        Стажер-разработчик (машинное обучение)
# 57                             Программист C/С++
# 87   Ведущий программист С++ проекты с сфере IoT
# 88                    Инженер-программист АСУ ТП
# 91                        Инженер-программист C#
# 120                              Программист C++
#
#                                                snippet                salary  \
# 72   Поддержка и дальнейшее развитие проектов для а...       от 120 000 руб.
# 136  Разработка программного обеспечения управления...  85 000 — 95 000 руб.
# 5    Обязательно: Уверенное владение C++, STL. Хоро...   80 000-120 000 руб.
# 8    Хорошее знание Swift. Желательно знание С++. Ж...   80 000-120 000 руб.
# 37   Отличное знание C++. Желательно знакомство с Q...   80 000-120 000 руб.
# 135  Разработка отдельных модулей специального прог...  75 000 — 85 000 руб.
# 47   Отличное знание Java, Kotlin. Желательно знани...   70 000-120 000 руб.
# 1    QT framework. Знание паттернов, разработка мно...   60 000-100 000 руб.
# 0    Отличное знание C++. Умение разбираться в чужо...   60 000-100 000 руб.
# 119  Распределение работы между подчинёнными и конт...          200 000 руб.
# 15   Знание С++ или Python. Отличное знание алгорит...                     -
# 14   Хорошая алгоритмическая подготовка. Знание С++...                     -
# 57   Предыдущий опыт и интерес создания ПО на языке...                     -
# 87   Разработка и экспертиза архитектуры систем. Фо...
# 88   Программирование и настройка приборов "полевог...
# 91   Разработка ПО с использованием стеков - ASP.NE...
# 120  Разработка ПО для Windows и Linux с применение...
#
#                    employer                                       vacancy_link
# 72                 СТОЛИЧКИ  https://www.superjob.ru/vakansii/programmist-c...
# 136                    НРТБ  https://www.superjob.ru/vakansii/veduschij-inz...
# 5                 АО РАКУРС                     https://hh.ru/vacancy/32666256
# 8            Cappasity Inc.                     https://hh.ru/vacancy/31399856
# 37           Cappasity Inc.                     https://hh.ru/vacancy/32543357
# 135                    НРТБ  https://www.superjob.ru/vakansii/inzhener-prog...
# 47           Cappasity Inc.                     https://hh.ru/vacancy/32379471
# 1            Cappasity Inc.                     https://hh.ru/vacancy/31273030
# 0            Cappasity Inc.                     https://hh.ru/vacancy/32323917
# 119  Торговая Сеть Управдом  https://www.superjob.ru/vakansii/rukovoditel-g...
# 15                   Яндекс                     https://hh.ru/vacancy/31938413
# 14                   Яндекс                     https://hh.ru/vacancy/32537820
# 57                  ООО НТБ                     https://hh.ru/vacancy/32548282
# 87                Мособлгаз  https://www.superjob.ru/vakansii/veduschij-pro...
# 88          ИНТЕЛЛЕКТ-СТРОЙ  https://www.superjob.ru/vakansii/inzhener-prog...
# 91          Центральная ППК  https://www.superjob.ru/vakansii/inzhener-prog...
# 120              НТЦ УП РАН  https://www.superjob.ru/vakansii/programmist-c...
